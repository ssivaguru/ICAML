# %%
import numpy as np
import pandas as pd
import seaborn as sns
import keras as keras
import matplotlib.pyplot as plt
from sklearn import datasets, linear_model
from sklearn.metrics import classification_report,accuracy_score,f1_score, precision_score, recall_score, confusion_matrix,mean_squared_error,mean_absolute_error,precision_recall_fscore_support,precision_recall_curve, PrecisionRecallDisplay,roc_curve,auc,RocCurveDisplay
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA
from tensorflow.keras.layers import InputLayer
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from keras.regularizers import l2
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.feature_selection import SelectFromModel, mutual_info_classif, f_classif, SelectKBest
from imblearn.over_sampling import SMOTE

# %%
#df = pd.read_csv('/content/data.csv')
url = 'https://raw.githubusercontent.com/ssivaguru/ICAML/main/data.csv'
df = pd.read_csv(url)
df_cd = df.copy()

# %% [markdown]
# #**Data exploration**

# %%
df.head(5)
# Out:
#    Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 0          1                                           0.370594
# 1          1                                           0.464291
# 2          1                                           0.426071
# 3          1                                           0.399844
# 4          1                                           0.465022
#
#     ROA(A) before interest and % after tax  \
# 0                                 0.424389
# 1                                 0.538214
# 2                                 0.499019
# 3                                 0.451265
# 4                                 0.538432
#
#     ROA(B) before interest and depreciation after tax  \
# 0                                           0.405750
# 1                                           0.516730
# 2                                           0.472295
# 3                                           0.457733
# 4                                           0.522298
#
#     Operating Gross Margin   Realized Sales Gross Margin  \
# 0                 0.601457                      0.601457
# 1                 0.610235                      0.610235
# 2                 0.601450                      0.601364
# 3                 0.583541                      0.583541
# 4                 0.598783                      0.598783
#
#     Operating Profit Rate   Pre-tax net Interest Rate  \
# 0                0.998969                    0.796887
# 1                0.998946                    0.797380
# 2                0.998857                    0.796403
# 3                0.998700                    0.796967
# 4                0.998973                    0.797366
#
#     After-tax net Interest Rate   Non-industry income and expenditure/revenue  \
# 0                      0.808809                                      0.302646
# 1                      0.809301                                      0.303556
# 2                      0.808388                                      0.302035
# 3                      0.808966                                      0.303350
# 4                      0.809304                                      0.303475
#
#    ...   Net Income to Total Assets   Total assets to GNP price  \
# 0  ...                     0.716845                    0.009219
# 1  ...                     0.795297                    0.008323
# 2  ...                     0.774670                    0.040003
# 3  ...                     0.739555                    0.003252
# 4  ...                     0.795016                    0.003878
#
#     No-credit Interval   Gross Profit to Sales  \
# 0             0.622879                0.601453
# 1             0.623652                0.610237
# 2             0.623841                0.601449
# 3             0.622929                0.583538
# 4             0.623521                0.598782
#
#     Net Income to Stockholder's Equity   Liability to Equity  \
# 0                             0.827890              0.290202
# 1                             0.839969              0.283846
# 2                             0.836774              0.290189
# 3                             0.834697              0.281721
# 4                             0.839973              0.278514
#
#     Degree of Financial Leverage (DFL)  \
# 0                             0.026601
# 1                             0.264577
# 2                             0.026555
# 3                             0.026697
# 4                             0.024752
#
#     Interest Coverage Ratio (Interest expense to EBIT)   Net Income Flag  \
# 0                                           0.564050                   1
# 1                                           0.570175                   1
# 2                                           0.563706                   1
# 3                                           0.564663                   1
# 4                                           0.575617                   1
#
#     Equity to Liability
# 0              0.016469
# 1              0.020794
# 2              0.016474
# 3              0.023982
# 4              0.035490
#
# [5 rows x 96 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6819 entries, 0 to 6818
# Data columns (total 96 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   Bankrupt?                                                 6819 non-null   int64
#  1    ROA(C) before interest and depreciation before interest  6819 non-null   float64
#  2    ROA(A) before interest and % after tax                   6819 non-null   float64
#  3    ROA(B) before interest and depreciation after tax        6819 non-null   float64
#  4    Operating Gross Margin                                   6819 non-null   float64
#  5    Realized Sales Gross Margin                              6819 non-null   float64
#  6    Operating Profit Rate                                    6819 non-null   float64
#  7    Pre-tax net Interest Rate                                6819 non-null   float64
#  8    After-tax net Interest Rate                              6819 non-null   float64
#  9    Non-industry income and expenditure/revenue              6819 non-null   float64
#  10   Continuous interest rate (after tax)                     6819 non-null   float64
#  11   Operating Expense Rate                                   6819 non-null   float64
#  12   Research and development expense rate                    6819 non-null   float64
#  13   Cash flow rate                                           6819 non-null   float64
#  14   Interest-bearing debt interest rate                      6819 non-null   float64
#  15   Tax rate (A)                                             6819 non-null   float64
#  16   Net Value Per Share (B)                                  6819 non-null   float64
#  17   Net Value Per Share (A)                                  6819 non-null   float64
#  18   Net Value Per Share (C)                                  6819 non-null   float64
#  19   Persistent EPS in the Last Four Seasons                  6819 non-null   float64
#  20   Cash Flow Per Share                                      6819 non-null   float64
#  21   Revenue Per Share (Yuan ¥)                               6819 non-null   float64
#  22   Operating Profit Per Share (Yuan ¥)                      6819 non-null   float64
#  23   Per Share Net profit before tax (Yuan ¥)                 6819 non-null   float64
#  24   Realized Sales Gross Profit Growth Rate                  6819 non-null   float64
#  25   Operating Profit Growth Rate                             6819 non-null   float64
#  26   After-tax Net Profit Growth Rate                         6819 non-null   float64
#  27   Regular Net Profit Growth Rate                           6819 non-null   float64
#  28   Continuous Net Profit Growth Rate                        6819 non-null   float64
#  29   Total Asset Growth Rate                                  6819 non-null   float64
#  30   Net Value Growth Rate                                    6819 non-null   float64
#  31   Total Asset Return Growth Rate Ratio                     6819 non-null   float64
#  32   Cash Reinvestment %                                      6819 non-null   float64
#  33   Current Ratio                                            6819 non-null   float64
#  34   Quick Ratio                                              6819 non-null   float64
#  35   Interest Expense Ratio                                   6819 non-null   float64
#  36   Total debt/Total net worth                               6819 non-null   float64
#  37   Debt ratio %                                             6819 non-null   float64
#  38   Net worth/Assets                                         6819 non-null   float64
#  39   Long-term fund suitability ratio (A)                     6819 non-null   float64
#  40   Borrowing dependency                                     6819 non-null   float64
#  41   Contingent liabilities/Net worth                         6819 non-null   float64
#  42   Operating profit/Paid-in capital                         6819 non-null   float64
#  43   Net profit before tax/Paid-in capital                    6819 non-null   float64
#  44   Inventory and accounts receivable/Net value              6819 non-null   float64
#  45   Total Asset Turnover                                     6819 non-null   float64
#  46   Accounts Receivable Turnover                             6819 non-null   float64
#  47   Average Collection Days                                  6819 non-null   float64
#  48   Inventory Turnover Rate (times)                          6819 non-null   float64
#  49   Fixed Assets Turnover Frequency                          6819 non-null   float64
#  50   Net Worth Turnover Rate (times)                          6819 non-null   float64
#  51   Revenue per person                                       6819 non-null   float64
#  52   Operating profit per person                              6819 non-null   float64
#  53   Allocation rate per person                               6819 non-null   float64
#  54   Working Capital to Total Assets                          6819 non-null   float64
#  55   Quick Assets/Total Assets                                6819 non-null   float64
#  56   Current Assets/Total Assets                              6819 non-null   float64
#  57   Cash/Total Assets                                        6819 non-null   float64
#  58   Quick Assets/Current Liability                           6819 non-null   float64
#  59   Cash/Current Liability                                   6819 non-null   float64
#  60   Current Liability to Assets                              6819 non-null   float64
#  61   Operating Funds to Liability                             6819 non-null   float64
#  62   Inventory/Working Capital                                6819 non-null   float64
#  63   Inventory/Current Liability                              6819 non-null   float64
#  64   Current Liabilities/Liability                            6819 non-null   float64
#  65   Working Capital/Equity                                   6819 non-null   float64
#  66   Current Liabilities/Equity                               6819 non-null   float64
#  67   Long-term Liability to Current Assets                    6819 non-null   float64
#  68   Retained Earnings to Total Assets                        6819 non-null   float64
#  69   Total income/Total expense                               6819 non-null   float64
#  70   Total expense/Assets                                     6819 non-null   float64
#  71   Current Asset Turnover Rate                              6819 non-null   float64
#  72   Quick Asset Turnover Rate                                6819 non-null   float64
#  73   Working capitcal Turnover Rate                           6819 non-null   float64
#  74   Cash Turnover Rate                                       6819 non-null   float64
#  75   Cash Flow to Sales                                       6819 non-null   float64
#  76   Fixed Assets to Assets                                   6819 non-null   float64
#  77   Current Liability to Liability                           6819 non-null   float64
#  78   Current Liability to Equity                              6819 non-null   float64
#  79   Equity to Long-term Liability                            6819 non-null   float64
#  80   Cash Flow to Total Assets                                6819 non-null   float64
#  81   Cash Flow to Liability                                   6819 non-null   float64
#  82   CFO to Assets                                            6819 non-null   float64
#  83   Cash Flow to Equity                                      6819 non-null   float64
#  84   Current Liability to Current Assets                      6819 non-null   float64
#  85   Liability-Assets Flag                                    6819 non-null   int64
#  86   Net Income to Total Assets                               6819 non-null   float64
#  87   Total assets to GNP price                                6819 non-null   float64
#  88   No-credit Interval                                       6819 non-null   float64
#  89   Gross Profit to Sales                                    6819 non-null   float64
#  90   Net Income to Stockholder's Equity                       6819 non-null   float64
#  91   Liability to Equity                                      6819 non-null   float64
#  92   Degree of Financial Leverage (DFL)                       6819 non-null   float64
#  93   Interest Coverage Ratio (Interest expense to EBIT)       6819 non-null   float64
#  94   Net Income Flag                                          6819 non-null   int64
#  95   Equity to Liability                                      6819 non-null   float64
# dtypes: float64(93), int64(3)
# memory usage: 5.0 MB

# %%
df.describe()
# Out:
#          Bankrupt?   ROA(C) before interest and depreciation before interest  \
# count  6819.000000                                        6819.000000
# mean      0.032263                                           0.505180
# std       0.176710                                           0.060686
# min       0.000000                                           0.000000
# 25%       0.000000                                           0.476527
# 50%       0.000000                                           0.502706
# 75%       0.000000                                           0.535563
# max       1.000000                                           1.000000
#
#         ROA(A) before interest and % after tax  \
# count                              6819.000000
# mean                                  0.558625
# std                                   0.065620
# min                                   0.000000
# 25%                                   0.535543
# 50%                                   0.559802
# 75%                                   0.589157
# max                                   1.000000
#
#         ROA(B) before interest and depreciation after tax  \
# count                                        6819.000000
# mean                                            0.553589
# std                                             0.061595
# min                                             0.000000
# 25%                                             0.527277
# 50%                                             0.552278
# 75%                                             0.584105
# max                                             1.000000
#
#         Operating Gross Margin   Realized Sales Gross Margin  \
# count              6819.000000                   6819.000000
# mean                  0.607948                      0.607929
# std                   0.016934                      0.016916
# min                   0.000000                      0.000000
# 25%                   0.600445                      0.600434
# 50%                   0.605997                      0.605976
# 75%                   0.613914                      0.613842
# max                   1.000000                      1.000000
#
#         Operating Profit Rate   Pre-tax net Interest Rate  \
# count             6819.000000                 6819.000000
# mean                 0.998755                    0.797190
# std                  0.013010                    0.012869
# min                  0.000000                    0.000000
# 25%                  0.998969                    0.797386
# 50%                  0.999022                    0.797464
# 75%                  0.999095                    0.797579
# max                  1.000000                    1.000000
#
#         After-tax net Interest Rate  \
# count                   6819.000000
# mean                       0.809084
# std                        0.013601
# min                        0.000000
# 25%                        0.809312
# 50%                        0.809375
# 75%                        0.809469
# max                        1.000000
#
#         Non-industry income and expenditure/revenue  ...  \
# count                                   6819.000000  ...
# mean                                       0.303623  ...
# std                                        0.011163  ...
# min                                        0.000000  ...
# 25%                                        0.303466  ...
# 50%                                        0.303525  ...
# 75%                                        0.303585  ...
# max                                        1.000000  ...
#
#         Net Income to Total Assets   Total assets to GNP price  \
# count                  6819.000000                6.819000e+03
# mean                      0.807760                1.862942e+07
# std                       0.040332                3.764501e+08
# min                       0.000000                0.000000e+00
# 25%                       0.796750                9.036205e-04
# 50%                       0.810619                2.085213e-03
# 75%                       0.826455                5.269777e-03
# max                       1.000000                9.820000e+09
#
#         No-credit Interval   Gross Profit to Sales  \
# count          6819.000000             6819.000000
# mean              0.623915                0.607946
# std               0.012290                0.016934
# min               0.000000                0.000000
# 25%               0.623636                0.600443
# 50%               0.623879                0.605998
# 75%               0.624168                0.613913
# max               1.000000                1.000000
#
#         Net Income to Stockholder's Equity   Liability to Equity  \
# count                          6819.000000           6819.000000
# mean                              0.840402              0.280365
# std                               0.014523              0.014463
# min                               0.000000              0.000000
# 25%                               0.840115              0.276944
# 50%                               0.841179              0.278778
# 75%                               0.842357              0.281449
# max                               1.000000              1.000000
#
#         Degree of Financial Leverage (DFL)  \
# count                          6819.000000
# mean                              0.027541
# std                               0.015668
# min                               0.000000
# 25%                               0.026791
# 50%                               0.026808
# 75%                               0.026913
# max                               1.000000
#
#         Interest Coverage Ratio (Interest expense to EBIT)   Net Income Flag  \
# count                                        6819.000000              6819.0
# mean                                            0.565358                 1.0
# std                                             0.013214                 0.0
# min                                             0.000000                 1.0
# 25%                                             0.565158                 1.0
# 50%                                             0.565252                 1.0
# 75%                                             0.565725                 1.0
# max                                             1.000000                 1.0
#
#         Equity to Liability
# count           6819.000000
# mean               0.047578
# std                0.050014
# min                0.000000
# 25%                0.024477
# 50%                0.033798
# 75%                0.052838
# max                1.000000
#
# [8 rows x 96 columns]

# %%
df.isnull().sum()
[print(col) for col in df if df[col].isna().sum() > 0]
# Out:
# []

# %%
sns.countplot(x=df['Bankrupt?'])
plt.title('Class distribution for the target feature :: Imbalanced Dataset')
# Out:
# Text(0.5, 1.0, 'Class distribution for the target feature :: Imbalanced Dataset')

# %%
sns.set_theme(context = 'paper')
df.hist(figsize = (35,30), bins = 50)
plt.show()

# %%
f, axes = plt.subplots(ncols=7, figsize=(30,6))

sns.boxplot(x='Bankrupt?', y=" Net Income to Total Assets", data=df, ax=axes[0])
axes[0].set_title('Bankrupt vs Net Income to Total Assets')

sns.boxplot(x='Bankrupt?', y=" Operating Profit Per Share (Yuan ¥)", data=df, ax=axes[1]) 
axes[1].set_title('Bankrupt vs Operating Profit Per Share (Yuan ¥)')


sns.boxplot(x='Bankrupt?', y=" Debt ratio %", data=df, ax=axes[2])
axes[2].set_title('Bankrupt vs Debt ratio Correlation')


sns.boxplot(x='Bankrupt?', y=" Liability to Equity", data=df, ax=axes[3])  
axes[3].set_title('Bankrupt vs Liability to Equity') 

sns.boxplot(x='Bankrupt?', y=" ROA(C) before interest and depreciation before interest", data=df, ax=axes[4])  
axes[4].set_title('Bankrupt vs  ROA(C)') 

sns.boxplot(x='Bankrupt?', y=" ROA(B) before interest and depreciation after tax", data=df, ax=axes[5])  
axes[5].set_title('Bankrupt vs  ROA(B)') 

sns.boxplot(x='Bankrupt?', y=" ROA(A) before interest and % after tax", data=df, ax=axes[6])  
axes[6].set_title('Bankrupt vs ROA(A)') 

plt.show()

# %%
X=df.drop(labels=['Bankrupt?'], axis=1)
y=df['Bankrupt?']

# %%
feature_selection=SelectKBest(f_classif,k=30).fit(X,y)
sel_fts=X.columns[feature_selection.get_support()]
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/feature_selection/_univariate_selection.py:112: UserWarning: Features [93] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx, UserWarning)
# /usr/local/lib/python3.9/dist-packages/sklearn/feature_selection/_univariate_selection.py:113: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw

# %%
print(sel_fts)
# Out:
# Index([' ROA(C) before interest and depreciation before interest',
#        ' ROA(A) before interest and % after tax',
#        ' ROA(B) before interest and depreciation after tax', ' Tax rate (A)',
#        ' Net Value Per Share (B)', ' Net Value Per Share (A)',
#        ' Net Value Per Share (C)', ' Persistent EPS in the Last Four Seasons',
#        ' Operating Profit Per Share (Yuan ¥)',
#        ' Per Share Net profit before tax (Yuan ¥)', ' Debt ratio %',
#        ' Net worth/Assets', ' Borrowing dependency',
#        ' Operating profit/Paid-in capital',
#        ' Net profit before tax/Paid-in capital',
#        ' Working Capital to Total Assets', ' Cash/Total Assets',
#        ' Current Liability to Assets', ' Working Capital/Equity',
#        ' Current Liabilities/Equity', ' Retained Earnings to Total Assets',
#        ' Total expense/Assets', ' Current Liability to Equity',
#        ' Equity to Long-term Liability', ' CFO to Assets',
#        ' Current Liability to Current Assets', ' Liability-Assets Flag',
#        ' Net Income to Total Assets', ' Net Income to Stockholder's Equity',
#        ' Liability to Equity'],
#       dtype='object')

# %%
scaler=StandardScaler()
X_scale_ib=scaler.fit_transform(X)
X_train_ib, X_test_ib, y_train_ib, y_test_ib = train_test_split(X_scale_ib, y, train_size=0.8, shuffle=True, random_state=1, stratify=y) #imbalanced Dataset

# %%
Balanced_X=df[df.columns[df.columns.isin(sel_fts)]]

# %%
Bal_X = Balanced_X.copy()
Bal_X["Bankrupt?"] = df['Bankrupt?'] 
f, (ax1) = plt.subplots(1, figsize = (30,30))
corr = Bal_X.corr()
sns.heatmap(corr, cmap = 'coolwarm_r', ax= ax1)
ax1.set_title("Top 30 features correlatio Matrix")
# Out:
# Text(0.5, 1.0, 'Top 30 features correlatio Matrix')

# %%
oversample = SMOTE()
X,y=oversample.fit_resample(Balanced_X,y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.3)

# %%
sns.countplot(x=y)
# Out:
# <Axes: xlabel='Bankrupt?', ylabel='count'>

# %%
scaler=StandardScaler()
X_smote=scaler.fit_transform(X)

# %% [markdown]
# #**MODELS**
#
# Abbreviations:
# 1. IB- Imabalanced
# 2. RF- Reduced features/feature_selection

# %% [markdown]
# #**Logistic Regression**
#
# 1.   without SMOTE
# 2.   with SMOTE

# %% [markdown]
# ##**with IB Data**

# %%
LR_ib=LogisticRegression(solver = "liblinear" , penalty = "l1",max_iter=1500)
LR_ib.fit(X_train_ib,y_train_ib)
y_pred_ib=LR_ib.predict(X_test_ib)
print(classification_report(y_test_ib,y_pred_ib))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      1320
#            1       0.39      0.16      0.23        44
#
#     accuracy                           0.96      1364
#    macro avg       0.68      0.58      0.60      1364
# weighted avg       0.95      0.96      0.96      1364

# %%
from sklearn.metrics import precision_recall_curve, PrecisionRecallDisplay,roc_curve,auc,RocCurveDisplay
# ROC curve
fpr_ib, tpr_ib, thresholds_ib = roc_curve(y_test_ib, y_pred_ib)
roc_auc_ib = auc(fpr_ib, tpr_ib)
roc_display_ib = RocCurveDisplay(fpr=fpr_ib, tpr=tpr_ib, roc_auc=roc_auc_ib)
roc_display_ib.plot()


# PR Curve
from sklearn.metrics import precision_recall_curve, PrecisionRecallDisplay
precision_ib,recall_ib, thresholds_ib = precision_recall_curve(y_test_ib,y_pred_ib)
pr_display_ib = PrecisionRecallDisplay(precision_ib, recall_ib)
pr_display_ib.plot()

# %% [markdown]
# ##**with RF+SMOTE**

# %%
LR=LogisticRegression(max_iter=1500)
LR.fit(X_train,y_train)
# Out:
# LogisticRegression(max_iter=1500)

# %%
y_pred=LR.predict(X_test)
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.85      0.87      2030
#            1       0.85      0.89      0.87      1930
#
#     accuracy                           0.87      3960
#    macro avg       0.87      0.87      0.87      3960
# weighted avg       0.87      0.87      0.87      3960

# %%
y_pred[y_pred > 0.5] = 1
y_pred[y_pred <= 0.5] = 0

print(y_pred.shape)
print(y_test.shape)

#f1, precision, and recall scores
print("precision:", precision_score(y_test, y_pred , average="macro"))
print("Recall:", recall_score(y_test, y_pred , average="macro"))
print("F1_score:", f1_score(y_test, y_pred , average="macro"))
# Out:
# (3960,)
# (3960,)
# precision: 0.8658223516409316
# Recall: 0.8658988233492433
# F1_score: 0.8654033451733854

# %%
mse = mean_squared_error(y_test,y_pred)
print("Mean Squared Error: {}".format(mse))

## R2 score for training and testing
r2_train = LR.score(X_train,y_train)
r2_test = LR.score(X_test,y_test)
print("R² Score of linear regressor on training set: {}".format(r2_train))
print("R² Score of linear regressor on test set: {}".format(r2_test))
# Out:
# Mean Squared Error: 0.1345959595959596
# R² Score of linear regressor on training set: 0.8773544057155228
# R² Score of linear regressor on test set: 0.8654040404040404

# %%
print(LR.coef_)
# Out:
# [[-5.54307501 -3.58856723 -5.30018892 -0.31055153 -2.19834487 -2.12098166
#   -1.98718456 -4.70389725 -0.91223841 -3.38658326  8.16945911 -8.16919221
#    1.67166272 -0.87923599 -3.51625161 -4.02718186 -6.14918764  0.83102426
#   -0.87309453 -0.27544907 -1.14905854 -2.17226477 -0.27544907  1.45377194
#   -1.05961501  0.6380255  -1.66781844 -4.05037273 -0.04625886  0.06624742]]

# %%
from sklearn.metrics import precision_recall_curve, PrecisionRecallDisplay,roc_curve,auc,RocCurveDisplay
# ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)
roc_display = RocCurveDisplay(fpr=fpr, tpr=tpr, roc_auc=roc_auc)
roc_display.plot()


# PR Curve
from sklearn.metrics import precision_recall_curve, PrecisionRecallDisplay
precision,recall, thresholds = precision_recall_curve(y_test,y_pred)
pr_display = PrecisionRecallDisplay(precision, recall)
pr_display.plot()

# %% [markdown]
# #**LDA**

# %% [markdown]
# ##**with RF_SMOTE**

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

LDA = LinearDiscriminantAnalysis( n_components=1, priors=[0.75, 0.25])
LDA.fit(X_train, y_train)
LinearDiscriminantAnalysis()
# Out:
# LinearDiscriminantAnalysis()

# %%
print(LDA.priors_)
# Out:
# [0.75 0.25]

# %%
y_pred_LDA=LDA.predict(X_test)
print(classification_report(y_test,y_pred_LDA))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.93      0.86      2030
#            1       0.92      0.75      0.82      1930
#
#     accuracy                           0.84      3960
#    macro avg       0.86      0.84      0.84      3960
# weighted avg       0.85      0.84      0.84      3960

# %%
y_pred_LDA[y_pred_LDA > 0.3] = 1
y_pred_LDA[y_pred_LDA <= 0.3] = 0

print(y_pred_LDA.shape)
print(y_test.shape)

#f1, precision, and recall scores
print("precision:", precision_score(y_test, y_pred_LDA , average="macro"))
print("Recall:", recall_score(y_test, y_pred_LDA , average="macro"))
print("F1_score:", f1_score(y_test, y_pred_LDA , average="macro"))
# Out:
# (3960,)
# (3960,)
# precision: 0.8561085175232686
# Recall: 0.8418655402128692
# F1_score: 0.8421627805014715

# %%
fpr_LDA, tpr_LDA, thresholds_LDA = roc_curve(y_test, y_pred_LDA)
roc_auc_LDA = auc(fpr_LDA, tpr_LDA)
roc_display_LDA = RocCurveDisplay(fpr=fpr_LDA, tpr=tpr_LDA, roc_auc=roc_auc_LDA)
roc_display_LDA.plot()


# PR Curve
from sklearn.metrics import precision_recall_curve, PrecisionRecallDisplay
precision_LDA,recall_LDA, thresholds_LDA = precision_recall_curve(y_test,y_pred_LDA)
pr_display_LDA = PrecisionRecallDisplay(precision_LDA, recall_LDA)
pr_display_LDA.plot()

# %% [markdown]
# #**Polynomial Regression**
#
# 1. without SMOTE
# 2. with SMOTE

# %% [markdown]
# ##**with IB Data**

# %%
poly_ib = PolynomialFeatures(degree = 3, interaction_only=False, include_bias=False)
X_poly_ib = poly_ib.fit_transform(X_train_ib)
X_poly_ib.shape
# Out:
# (5455, 152095)

# %%
# pr_ib = LogisticRegression(penalty='l2',max_iter=2000)
# pr_ib.fit(X_poly_ib,y_train_ib)

# %%
# X_test_poly_ib = poly_ib.fit_transform(X_test_ib)
# y_pred_poly_ib=pr_ib.predict(X_test_poly_ib)

# y_pred_poly_ib[y_pred_poly_ib > 0.5] = 1
# y_pred_poly_ib[y_pred_poly_ib <= 0.5] = 0

# print(y_pred_poly_ib.shape)
# print(y_test_ib.shape)

# f1, precision, and recall scores
# print("precision:", precision_score(y_test_ib, y_pred_poly_ib , average="macro"))
# print("Recall:", recall_score(y_test_ib, y_pred_poly_ib , average="macro"))
# print("F1_score:", f1_score(y_test_ib, y_pred_poly_ib , average="macro"))

# %%
# mse_ib = mean_squared_error(y_test_ib,y_pred_poly_ib)
# print("Mean Squared Error: {}".format(mse_ib))

# ## R2 score for training and testing
# r2_train_ib = log_reg.score(X_train_ib,y_train_ib)
# r2_test_ib = log_reg.score(X_test_ib,y_test_ib)
# print("R² Score of linear regressor on training set: {}".format(r2_train_ib))
# print("R² Score of linear regressor on test set: {}".format(r2_test_ib))

# %%
# fpr_poly_ib, tpr_poly_ib, thresholds_poly_ib = roc_curve(y_test_ib, y_pred_poly_ib)
# roc_auc_poly_ib = auc(fpr_poly_ib, tpr_poly_ib)
# roc_display_poly_ib = RocCurveDisplay(fpr=fpr_poly_ib, tpr=tpr_poly_ib, roc_auc=roc_auc_poly_ib)
# roc_display_poly_ib.plot()

# precision_poly_ib,recall_poly_ib, thresholds_poly_ib = precision_recall_curve(y_test_ib,y_pred_poly_ib)
# pr_display_poly_ib = PrecisionRecallDisplay(precision_poly_ib, recall_poly_ib)
# pr_display_poly_ib.plot()

# %% [markdown]
# ##**with RF+SMOTE**

# %%
poly = PolynomialFeatures(degree = 3, interaction_only=False, include_bias=False)
X_poly = poly.fit_transform(X_train)
X_poly.shape
# Out:
# (9238, 5455)

# %%
pr = LogisticRegression(penalty='l2',max_iter=2000)
pr.fit(X_poly,y_train)
# Out:
# LogisticRegression(max_iter=2000)

# %%
X_test_poly = poly.fit_transform(X_test)
y_pred_poly=pr.predict(X_test_poly)

# %%
y_pred_poly[y_pred_poly > 0.5] = 1
y_pred_poly[y_pred_poly <= 0.5] = 0

print(y_pred_poly.shape)
print(y_test.shape)

# f1, precision, and recall scores
print("precision:", precision_score(y_test, y_pred_poly , average="macro"))
print("Recall:", recall_score(y_test, y_pred_poly , average="macro"))
print("F1_score:", f1_score(y_test, y_pred_poly , average="macro"))
# Out:
# (3960,)
# (3960,)
# precision: 0.8701905083360313
# Recall: 0.8703578447637765
# F1_score: 0.8699451077034216

# %%
mse = mean_squared_error(y_test,y_pred_poly)
print("Mean Squared Error: {}".format(mse))

## R2 score for training and testing
r2_train = LR.score(X_train,y_train)
r2_test = LR.score(X_test,y_test)
print("R² Score of linear regressor on training set: {}".format(r2_train))
print("R² Score of linear regressor on test set: {}".format(r2_test))
# Out:
# Mean Squared Error: 0.13005050505050506
# R² Score of linear regressor on training set: 0.8773544057155228
# R² Score of linear regressor on test set: 0.8654040404040404

# %%
fpr_poly, tpr_poly, thresholds_poly = roc_curve(y_test, y_pred_poly)
roc_auc_poly = auc(fpr_poly, tpr_poly)
roc_display_poly = RocCurveDisplay(fpr=fpr_poly, tpr=tpr_poly, roc_auc=roc_auc_poly)
roc_display_poly.plot()


# PR Curve
from sklearn.metrics import precision_recall_curve, PrecisionRecallDisplay
precision_poly,recall_poly, thresholds_poly = precision_recall_curve(y_test,y_pred_poly)
pr_display_poly = PrecisionRecallDisplay(precision_poly, recall_poly)
pr_display_poly.plot()

# %% [markdown]
# #**Decision Trees**

# %% [markdown]
# ##**with IB Data**

# %%
from sklearn import tree
X_DT=df.drop(labels=['Bankrupt?'], axis=1)
y_DT=df['Bankrupt?']
DT_ib = tree.DecisionTreeClassifier(criterion='gini',max_depth=10,max_features=11,random_state=42)
DT_ib = DT_ib.fit(X_train_ib, y_train_ib)
y_pred_DT_ib=DT_ib.predict(X_test_ib)
print(classification_report(y_test_ib,y_pred_DT_ib))
y_class_names=["0","1"]
sel_fts.shape
X_col_names = list(X_DT.columns)
import graphviz

CBD_data_ib = tree.export_graphviz(DT_ib, out_file=None, 
                                feature_names=X_col_names,  
                                class_names=y_class_names,
                                filled=True)


graph_ib = graphviz.Source(CBD_data_ib, format="png") 
graph_ib
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      1320
#            1       0.31      0.25      0.28        44
#
#     accuracy                           0.96      1364
#    macro avg       0.64      0.62      0.63      1364
# weighted avg       0.95      0.96      0.96      1364

# %%
fpr_dt_ib, tpr_dt_ib, thresholds_dt_ib = roc_curve(y_test_ib, y_pred_DT_ib)
roc_auc_dt_ib = auc(fpr_dt_ib, tpr_dt_ib)
roc_display_dt_ib = RocCurveDisplay(fpr=fpr_dt_ib, tpr=tpr_dt_ib, roc_auc=roc_auc_dt_ib)
roc_display_dt_ib.plot()


# PR Curve
from sklearn.metrics import precision_recall_curve, PrecisionRecallDisplay
precision_dt_ib,recall_dt_ib, thresholds_dt_ib = precision_recall_curve(y_test_ib,y_pred_DT_ib)
pr_display_dt_ib = PrecisionRecallDisplay(precision_dt_ib, recall_dt_ib)
pr_display_dt_ib.plot()

# %% [markdown]
# ##**with RF+SMOTE**

# %%
from sklearn import tree
DT = tree.DecisionTreeClassifier(criterion='gini',max_depth=10,max_features=11,random_state=42)
DT = DT.fit(X_train, y_train)
y_pred_DT=DT.predict(X_test)
print(classification_report(y_test,y_pred_DT))
y_class_names=["0","1"]
sel_fts.shape
X_col_names = list(df.columns[df.columns.isin(sel_fts)])
import graphviz

CBD_data = tree.export_graphviz(DT, out_file=None, 
                                feature_names=X_col_names,  
                                class_names=y_class_names,
                                filled=True)


graph = graphviz.Source(CBD_data, format="png") 
graph

# %%
fpr_dt, tpr_dt, thresholds_dt = roc_curve(y_test, y_pred_DT)
roc_auc_dt = auc(fpr_dt, tpr_dt)
roc_display_dt = RocCurveDisplay(fpr=fpr_dt, tpr=tpr_dt, roc_auc=roc_auc_dt)
roc_display_dt.plot()


# PR Curve
from sklearn.metrics import precision_recall_curve, PrecisionRecallDisplay
precision_dt,recall_dt, thresholds_dt = precision_recall_curve(y_test,y_pred_DT)
pr_display_dt = PrecisionRecallDisplay(precision_dt, recall_dt)
pr_display_dt.plot()

# %% [markdown]
# #**Neural Network**

# %% [markdown]
# ##**with weighted NN IB Data**

# %%
CBP_NN_IB = Sequential([InputLayer(input_shape=(X_train_ib.shape[1])),
                     Dense(64,activation="relu"),
                     Dense(1,activation="sigmoid")
                     ])

CBP_NN_IB.compile(optimizer="Adam",
                loss = "BinaryCrossentropy",
                metrics = "Accuracy")

CBP_NN_IB.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                6144
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 6,209
# Trainable params: 6,209
# Non-trainable params: 0
# _________________________________________________________________

# %%
weights = {0:1, 1:2000}
history = CBP_NN_IB.fit(X_train_ib, y_train_ib, epochs=70,class_weight=weights)
# Out:
# Epoch 1/70
# 171/171 [==============================] - 9s 3ms/step - loss: 10.3091 - Accuracy: 0.2979
# Epoch 2/70
# 171/171 [==============================] - 1s 3ms/step - loss: 3.5474 - Accuracy: 0.2836
# Epoch 3/70
# 171/171 [==============================] - 1s 4ms/step - loss: 3.0034 - Accuracy: 0.2797
# Epoch 4/70
# 171/171 [==============================] - 1s 5ms/step - loss: 2.7968 - Accuracy: 0.2788
# Epoch 5/70
# 171/171 [==============================] - 1s 5ms/step - loss: 2.6707 - Accuracy: 0.2942
# Epoch 6/70
# 171/171 [==============================] - 1s 5ms/step - loss: 2.5578 - Accuracy: 0.3003
# Epoch 7/70
# 171/171 [==============================] - 1s 3ms/step - loss: 2.4745 - Accuracy: 0.3274
# Epoch 8/70
# 171/171 [==============================] - 1s 3ms/step - loss: 2.3906 - Accuracy: 0.3456
# Epoch 9/70
# 171/171 [==============================] - 1s 3ms/step - loss: 2.3152 - Accuracy: 0.3688
# Epoch 10/70
# 171/171 [==============================] - 1s 3ms/step - loss: 2.2523 - Accuracy: 0.3949
# Epoch 11/70
# 171/171 [==============================] - 1s 3ms/step - loss: 2.1753 - Accuracy: 0.4169
# Epoch 12/70
# 171/171 [==============================] - 1s 3ms/step - loss: 2.1182 - Accuracy: 0.4429
# Epoch 13/70
# 171/171 [==============================] - 1s 3ms/step - loss: 2.0561 - Accuracy: 0.4643
# Epoch 14/70
# 171/171 [==============================] - 1s 3ms/step - loss: 1.9769 - Accuracy: 0.4775
# Epoch 15/70
# 171/171 [==============================] - 1s 3ms/step - loss: 1.9338 - Accuracy: 0.5010
# Epoch 16/70
# 171/171 [==============================] - 1s 3ms/step - loss: 1.8762 - Accuracy: 0.5221
# Epoch 17/70
# 171/171 [==============================] - 1s 3ms/step - loss: 1.8113 - Accuracy: 0.5406
# Epoch 18/70
# 171/171 [==============================] - 1s 3ms/step - loss: 1.7548 - Accuracy: 0.5544
# Epoch 19/70
# 171/171 [==============================] - 1s 3ms/step - loss: 1.7083 - Accuracy: 0.5751
# Epoch 20/70
# 171/171 [==============================] - 1s 3ms/step - loss: 1.6550 - Accuracy: 0.5855
# Epoch 21/70
# 171/171 [==============================] - 1s 3ms/step - loss: 1.5765 - Accuracy: 0.6000
# Epoch 22/70
# 171/171 [==============================] - 1s 3ms/step - loss: 1.5883 - Accuracy: 0.6137
# Epoch 23/70
# 171/171 [==============================] - 1s 3ms/step - loss: 1.5422 - Accuracy: 0.6207
# Epoch 24/70
# 171/171 [==============================] - 1s 4ms/step - loss: 1.5633 - Accuracy: 0.6442
# Epoch 25/70
# 171/171 [==============================] - 1s 5ms/step - loss: 1.5501 - Accuracy: 0.6163
# Epoch 26/70
# 171/171 [==============================] - 1s 5ms/step - loss: 1.4400 - Accuracy: 0.6434
# Epoch 27/70
# 171/171 [==============================] - 1s 4ms/step - loss: 1.3735 - Accuracy: 0.6587
# Epoch 28/70
# 171/171 [==============================] - 1s 3ms/step - loss: 1.3244 - Accuracy: 0.6700
# Epoch 29/70
# 171/171 [==============================] - 1s 3ms/step - loss: 1.3111 - Accuracy: 0.6884
# Epoch 30/70
# 171/171 [==============================] - 1s 3ms/step - loss: 1.2595 - Accuracy: 0.7017
# Epoch 31/70
# 171/171 [==============================] - 1s 3ms/step - loss: 1.2141 - Accuracy: 0.7142
# Epoch 32/70
# 171/171 [==============================] - 1s 3ms/step - loss: 1.1954 - Accuracy: 0.7160
# Epoch 33/70
# 171/171 [==============================] - 1s 3ms/step - loss: 1.1562 - Accuracy: 0.7313
# Epoch 34/70
# 171/171 [==============================] - 1s 3ms/step - loss: 1.1278 - Accuracy: 0.7327
# Epoch 35/70
# 171/171 [==============================] - 1s 3ms/step - loss: 1.1012 - Accuracy: 0.7476
# Epoch 36/70
# 171/171 [==============================] - 1s 3ms/step - loss: 1.0533 - Accuracy: 0.7507
# Epoch 37/70
# 171/171 [==============================] - 1s 3ms/step - loss: 1.0255 - Accuracy: 0.7597
# Epoch 38/70
# 171/171 [==============================] - 1s 5ms/step - loss: 1.0146 - Accuracy: 0.7698
# Epoch 39/70
# 171/171 [==============================] - 1s 6ms/step - loss: 0.9896 - Accuracy: 0.7800
# Epoch 40/70
# 171/171 [==============================] - 1s 5ms/step - loss: 0.9520 - Accuracy: 0.7809
# Epoch 41/70
# 171/171 [==============================] - 1s 5ms/step - loss: 0.9023 - Accuracy: 0.7925
# Epoch 42/70
# 171/171 [==============================] - 1s 8ms/step - loss: 0.9167 - Accuracy: 0.7945
# Epoch 43/70
# 171/171 [==============================] - 1s 5ms/step - loss: 0.9136 - Accuracy: 0.8000
# Epoch 44/70
# 171/171 [==============================] - 1s 4ms/step - loss: 0.8618 - Accuracy: 0.8141
# Epoch 45/70
# 171/171 [==============================] - 1s 4ms/step - loss: 0.8122 - Accuracy: 0.8187
# Epoch 46/70
# 171/171 [==============================] - 1s 3ms/step - loss: 0.8002 - Accuracy: 0.8258
# Epoch 47/70
# 171/171 [==============================] - 1s 3ms/step - loss: 0.7856 - Accuracy: 0.8324
# Epoch 48/70
# 171/171 [==============================] - 1s 3ms/step - loss: 0.7729 - Accuracy: 0.8345
# Epoch 49/70
# 171/171 [==============================] - 1s 3ms/step - loss: 0.7397 - Accuracy: 0.8414
# Epoch 50/70
# 171/171 [==============================] - 1s 3ms/step - loss: 0.7309 - Accuracy: 0.8425
# Epoch 51/70
# 171/171 [==============================] - 1s 4ms/step - loss: 0.7507 - Accuracy: 0.8466
# Epoch 52/70
# 171/171 [==============================] - 1s 4ms/step - loss: 0.8078 - Accuracy: 0.8418
# Epoch 53/70
# 171/171 [==============================] - 1s 3ms/step - loss: 0.7199 - Accuracy: 0.8508
# Epoch 54/70
# 171/171 [==============================] - 1s 3ms/step - loss: 0.6702 - Accuracy: 0.8581
# Epoch 55/70
# 171/171 [==============================] - 1s 3ms/step - loss: 0.6405 - Accuracy: 0.8620
# Epoch 56/70
# 171/171 [==============================] - 1s 3ms/step - loss: 0.6321 - Accuracy: 0.8658
# Epoch 57/70
# 171/171 [==============================] - 1s 3ms/step - loss: 0.6312 - Accuracy: 0.8669
# Epoch 58/70
# 171/171 [==============================] - 1s 3ms/step - loss: 0.6281 - Accuracy: 0.8656
# Epoch 59/70
# 171/171 [==============================] - 1s 3ms/step - loss: 0.5761 - Accuracy: 0.8785
# Epoch 60/70
# 171/171 [==============================] - 1s 4ms/step - loss: 0.5869 - Accuracy: 0.8770
# Epoch 61/70
# 171/171 [==============================] - 1s 3ms/step - loss: 0.5585 - Accuracy: 0.8816
# Epoch 62/70
# 171/171 [==============================] - 1s 4ms/step - loss: 0.5391 - Accuracy: 0.8860
# Epoch 63/70
# 171/171 [==============================] - 1s 4ms/step - loss: 0.5199 - Accuracy: 0.8918
# Epoch 64/70
# 171/171 [==============================] - 1s 4ms/step - loss: 0.5213 - Accuracy: 0.8920
# Epoch 65/70
# 171/171 [==============================] - 1s 5ms/step - loss: 0.5009 - Accuracy: 0.8962
# Epoch 66/70
# 171/171 [==============================] - 1s 3ms/step - loss: 0.5098 - Accuracy: 0.8933
# Epoch 67/70
# 171/171 [==============================] - 1s 3ms/step - loss: 0.4744 - Accuracy: 0.9021
# Epoch 68/70
# 171/171 [==============================] - 1s 3ms/step - loss: 0.4810 - Accuracy: 0.9010
# Epoch 69/70
# 171/171 [==============================] - 1s 3ms/step - loss: 0.4837 - Accuracy: 0.9060
# Epoch 70/70
# 171/171 [==============================] - 1s 3ms/step - loss: 0.4503 - Accuracy: 0.9083

# %%
y_pred_NN_IB=CBP_NN_IB.predict(X_test_ib)

y_pred_NN_IB[y_pred_NN_IB > 0.5] = 1
y_pred_NN_IB[y_pred_NN_IB <= 0.5] = 0


# f1, precision, and recall scores
print("precision:", precision_score(y_test_ib, y_pred_NN_IB , average="macro"))
print("Recall:", recall_score(y_test_ib, y_pred_NN_IB , average="macro"))
print("F1_score:", f1_score(y_test_ib, y_pred_NN_IB , average="macro"))
# Out:
# 43/43 [==============================] - 0s 2ms/step
# precision: 0.5867401086771948
# Recall: 0.781439393939394
# F1_score: 0.6169145569620254

# %%
from sklearn.metrics import precision_recall_curve, PrecisionRecallDisplay,roc_curve,auc,RocCurveDisplay
# ROC curve
fpr_NN_IB, tpr_NN_IB, thresholds_NN_IB = roc_curve(y_test_ib, y_pred_NN_IB)
roc_auc_NN_IB = auc(fpr_NN_IB, tpr_NN_IB)
roc_display_NN_IB = RocCurveDisplay(fpr=fpr_NN_IB, tpr=tpr_NN_IB, roc_auc=roc_auc_NN_IB)
roc_display_NN_IB.plot()


# PR Curve
from sklearn.metrics import precision_recall_curve, PrecisionRecallDisplay
precision_NN_IB,recall_NN_IB, thresholds_NN_IB = precision_recall_curve(y_test_ib,y_pred_NN_IB)
pr_display_NN_IB = PrecisionRecallDisplay(precision_NN_IB, recall_NN_IB)
pr_display_NN_IB.plot()

# %% [markdown]
# ##**with RF+SMOTE**

# %%
CBP_NN = Sequential([keras.Input(shape=(X_train.shape[1])),
                     Dense(84,activation="relu"),
                     Dense(20,activation="relu"),
                     Dense(1,activation="sigmoid")
                     ])

CBP_NN.compile(optimizer="Adam",
                loss = "BinaryCrossentropy",
                metrics = "Accuracy")

CBP_NN.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 84)                2604
#
#  dense_3 (Dense)             (None, 20)                1700
#
#  dense_4 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 4,325
# Trainable params: 4,325
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = CBP_NN.fit(X_train, y_train, epochs=30)
# Out:
# Epoch 1/30
# 289/289 [==============================] - 3s 3ms/step - loss: 0.4915 - Accuracy: 0.8047
# Epoch 2/30
# 289/289 [==============================] - 1s 3ms/step - loss: 0.3533 - Accuracy: 0.8597
# Epoch 3/30
# 289/289 [==============================] - 1s 3ms/step - loss: 0.3344 - Accuracy: 0.8637
# Epoch 4/30
# 289/289 [==============================] - 1s 3ms/step - loss: 0.3261 - Accuracy: 0.8673
# Epoch 5/30
# 289/289 [==============================] - 1s 3ms/step - loss: 0.3195 - Accuracy: 0.8684
# Epoch 6/30
# 289/289 [==============================] - 1s 3ms/step - loss: 0.3140 - Accuracy: 0.8700
# Epoch 7/30
# 289/289 [==============================] - 1s 3ms/step - loss: 0.3115 - Accuracy: 0.8717
# Epoch 8/30
# 289/289 [==============================] - 1s 3ms/step - loss: 0.3083 - Accuracy: 0.8718
# Epoch 9/30
# 289/289 [==============================] - 1s 3ms/step - loss: 0.3097 - Accuracy: 0.8689
# Epoch 10/30
# 289/289 [==============================] - 1s 5ms/step - loss: 0.3021 - Accuracy: 0.8744
# Epoch 11/30
# 289/289 [==============================] - 1s 4ms/step - loss: 0.3014 - Accuracy: 0.8758
# Epoch 12/30
# 289/289 [==============================] - 1s 3ms/step - loss: 0.2966 - Accuracy: 0.8748
# Epoch 13/30
# 289/289 [==============================] - 1s 3ms/step - loss: 0.2971 - Accuracy: 0.8745
# Epoch 14/30
# 289/289 [==============================] - 1s 3ms/step - loss: 0.2918 - Accuracy: 0.8778
# Epoch 15/30
# 289/289 [==============================] - 1s 3ms/step - loss: 0.2918 - Accuracy: 0.8802
# Epoch 16/30
# 289/289 [==============================] - 1s 3ms/step - loss: 0.2933 - Accuracy: 0.8752
# Epoch 17/30
# 289/289 [==============================] - 1s 3ms/step - loss: 0.2863 - Accuracy: 0.8804
# Epoch 18/30
# 289/289 [==============================] - 1s 3ms/step - loss: 0.2870 - Accuracy: 0.8801
# Epoch 19/30
# 289/289 [==============================] - 1s 3ms/step - loss: 0.2841 - Accuracy: 0.8828
# Epoch 20/30
# 289/289 [==============================] - 1s 3ms/step - loss: 0.2851 - Accuracy: 0.8815
# Epoch 21/30
# 289/289 [==============================] - 1s 3ms/step - loss: 0.2852 - Accuracy: 0.8826
# Epoch 22/30
# 289/289 [==============================] - 1s 4ms/step - loss: 0.2820 - Accuracy: 0.8832
# Epoch 23/30
# 289/289 [==============================] - 1s 5ms/step - loss: 0.2818 - Accuracy: 0.8810
# Epoch 24/30
# 289/289 [==============================] - 1s 3ms/step - loss: 0.2797 - Accuracy: 0.8850
# Epoch 25/30
# 289/289 [==============================] - 1s 3ms/step - loss: 0.2801 - Accuracy: 0.8835
# Epoch 26/30
# 289/289 [==============================] - 1s 3ms/step - loss: 0.2743 - Accuracy: 0.8860
# Epoch 27/30
# 289/289 [==============================] - 1s 3ms/step - loss: 0.2777 - Accuracy: 0.8828
# Epoch 28/30
# 289/289 [==============================] - 1s 5ms/step - loss: 0.2750 - Accuracy: 0.8844
# Epoch 29/30
# 289/289 [==============================] - 1s 3ms/step - loss: 0.2731 - Accuracy: 0.8866
# Epoch 30/30
# 289/289 [==============================] - 1s 3ms/step - loss: 0.2729 - Accuracy: 0.8868

# %%
y_pred_NN=CBP_NN.predict(X_test)
# Out:
# 124/124 [==============================] - 0s 1ms/step

# %%
y_pred_NN[y_pred_NN > 0.3] = 1
y_pred_NN[y_pred_NN <= 0.3] = 0


# f1, precision, and recall scores
print("precision:", precision_score(y_test, y_pred_NN , average="macro"))
print("Recall:", recall_score(y_test, y_pred_NN , average="macro"))
print("F1_score:", f1_score(y_test, y_pred_NN , average="macro"))
# Out:
# precision: 0.8816166082990535
# Recall: 0.8784540187345262
# F1_score: 0.8768728335254335

# %%
# ROC curve
fpr_NN, tpr_NN, thresholds_NN = roc_curve(y_test, y_pred_NN)
roc_auc_NN = auc(fpr_NN, tpr_NN)
roc_display_NN = RocCurveDisplay(fpr=fpr_NN, tpr=tpr_NN, roc_auc=roc_auc_NN)
roc_display_NN.plot()


# PR Curve
from sklearn.metrics import precision_recall_curve, PrecisionRecallDisplay
precision_NN,recall_NN, thresholds_NN = precision_recall_curve(y_test,y_pred_NN)
pr_display = PrecisionRecallDisplay(precision_NN, recall_NN)
pr_display.plot()

# %% [markdown]
# #**PCA**

# %% [markdown]
# ##**wighted NN + IB data**

# %%
n_components = 95
pca95pc = PCA(n_components)
pca95pc.fit(X_train_ib)
# Out:
# PCA(n_components=95)

# %%
plt.grid()
plt.plot(np.cumsum(pca95pc.explained_variance_ratio_))
plt.xlabel('Number of components')
plt.ylabel('Explained variance')
# Out:
# Text(0, 0.5, 'Explained variance')

# %%
pca_90_ib = PCA(n_components = 0.90)
pca_90_ib.fit(X_train_ib)
print("Cumulative Variances (Percentage):")
print(np.cumsum(pca_90_ib.explained_variance_ratio_ * 100))
components_ib = len(pca_90_ib.explained_variance_ratio_)
print(f'Number of components: {components_ib}')
# Out:
# Cumulative Variances (Percentage):
# [14.26545201 22.58944748 28.06165865 33.02224124 37.26280135 40.69005632
#  43.7978533  46.13647021 48.32297795 50.28406575 52.23076061 54.07224143
#  55.84230033 57.51594883 59.08650137 60.6249467  62.14414058 63.56717408
#  64.93957276 66.29695375 67.64106231 68.98276679 70.29116768 71.56792339
#  72.79807901 74.00252361 75.19813149 76.37284457 77.53834546 78.67880907
#  79.80792313 80.93185376 82.02756319 83.09379836 84.12343387 85.13157478
#  86.13031768 87.08646266 88.0132679  88.90927895 89.79527161 90.6487154 ]
# Number of components: 42

# %%
num_pca_modes_ib =44
pca_pc_ib = PCA(n_components=num_pca_modes_ib)
pca_pc_ib.fit(X_train_ib)

#pca90pc_comp  = abs(pca90pc.components_)
#print(pca90pc_comp)

X_train_red_ib = pca_pc_ib.transform(X_train_ib)

print("Train images shape:", X_train_red_ib.shape)
# Out:
# Train images shape: (5455, 44)

# %%
CBP_PCA_ib = Sequential([keras.Input(shape=(num_pca_modes_ib)),
                     Dense(64,activation="relu"),
                     Dense(30,activation="relu"),
                     Dense(20,activation="relu"),
                     Dense(1,activation="sigmoid")
                     ])

CBP_PCA_ib.compile(optimizer="Adam",
                loss = "BinaryCrossentropy",
                metrics = "Accuracy")

CBP_PCA_ib.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5 (Dense)             (None, 64)                2880
#
#  dense_6 (Dense)             (None, 30)                1950
#
#  dense_7 (Dense)             (None, 20)                620
#
#  dense_8 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 5,471
# Trainable params: 5,471
# Non-trainable params: 0
# _________________________________________________________________

# %%
weights_pca = {0:1, 1:20}
history = CBP_PCA_ib.fit(X_train_red_ib,y_train_ib, epochs=50, class_weight=weights_pca)
# Out:
# Epoch 1/50
# 171/171 [==============================] - 2s 4ms/step - loss: 0.8765 - Accuracy: 0.8414
# Epoch 2/50
# 171/171 [==============================] - 1s 5ms/step - loss: 0.6614 - Accuracy: 0.8748
# Epoch 3/50
# 171/171 [==============================] - 1s 5ms/step - loss: 0.4905 - Accuracy: 0.8794
# Epoch 4/50
# 171/171 [==============================] - 1s 5ms/step - loss: 0.4317 - Accuracy: 0.8984
# Epoch 5/50
# 171/171 [==============================] - 1s 4ms/step - loss: 0.4081 - Accuracy: 0.9045
# Epoch 6/50
# 171/171 [==============================] - 1s 4ms/step - loss: 0.3808 - Accuracy: 0.9096
# Epoch 7/50
# 171/171 [==============================] - 1s 3ms/step - loss: 0.3548 - Accuracy: 0.9142
# Epoch 8/50
# 171/171 [==============================] - 1s 4ms/step - loss: 0.3377 - Accuracy: 0.9168
# Epoch 9/50
# 171/171 [==============================] - 1s 4ms/step - loss: 0.3124 - Accuracy: 0.9247
# Epoch 10/50
# 171/171 [==============================] - 1s 4ms/step - loss: 0.2972 - Accuracy: 0.9276
# Epoch 11/50
# 171/171 [==============================] - 1s 4ms/step - loss: 0.2913 - Accuracy: 0.9248
# Epoch 12/50
# 171/171 [==============================] - 1s 3ms/step - loss: 0.2588 - Accuracy: 0.9327
# Epoch 13/50
# 171/171 [==============================] - 1s 4ms/step - loss: 0.2409 - Accuracy: 0.9399
# Epoch 14/50
# 171/171 [==============================] - 1s 4ms/step - loss: 0.2317 - Accuracy: 0.9375
# Epoch 15/50
# 171/171 [==============================] - 1s 3ms/step - loss: 0.2215 - Accuracy: 0.9445
# Epoch 16/50
# 171/171 [==============================] - 1s 4ms/step - loss: 0.1930 - Accuracy: 0.9514
# Epoch 17/50
# 171/171 [==============================] - 1s 4ms/step - loss: 0.1853 - Accuracy: 0.9509
# Epoch 18/50
# 171/171 [==============================] - 1s 4ms/step - loss: 0.1684 - Accuracy: 0.9560
# Epoch 19/50
# 171/171 [==============================] - 1s 4ms/step - loss: 0.1651 - Accuracy: 0.9544
# Epoch 20/50
# 171/171 [==============================] - 1s 3ms/step - loss: 0.1488 - Accuracy: 0.9602
# Epoch 21/50
# 171/171 [==============================] - 1s 5ms/step - loss: 0.1291 - Accuracy: 0.9637
# Epoch 22/50
# 171/171 [==============================] - 1s 5ms/step - loss: 0.1199 - Accuracy: 0.9668
# Epoch 23/50
# 171/171 [==============================] - 1s 5ms/step - loss: 0.1125 - Accuracy: 0.9692
# Epoch 24/50
# 171/171 [==============================] - 1s 4ms/step - loss: 0.1053 - Accuracy: 0.9727
# Epoch 25/50
# 171/171 [==============================] - 1s 3ms/step - loss: 0.1212 - Accuracy: 0.9679
# Epoch 26/50
# 171/171 [==============================] - 1s 4ms/step - loss: 0.1003 - Accuracy: 0.9753
# Epoch 27/50
# 171/171 [==============================] - 1s 4ms/step - loss: 0.1166 - Accuracy: 0.9721
# Epoch 28/50
# 171/171 [==============================] - 1s 4ms/step - loss: 0.2169 - Accuracy: 0.9676
# Epoch 29/50
# 171/171 [==============================] - 1s 4ms/step - loss: 0.0989 - Accuracy: 0.9762
# Epoch 30/50
# 171/171 [==============================] - 1s 3ms/step - loss: 0.0855 - Accuracy: 0.9806
# Epoch 31/50
# 171/171 [==============================] - 1s 4ms/step - loss: 0.0697 - Accuracy: 0.9839
# Epoch 32/50
# 171/171 [==============================] - 1s 3ms/step - loss: 0.0644 - Accuracy: 0.9844
# Epoch 33/50
# 171/171 [==============================] - 1s 4ms/step - loss: 0.0572 - Accuracy: 0.9852
# Epoch 34/50
# 171/171 [==============================] - 1s 4ms/step - loss: 0.0548 - Accuracy: 0.9868
# Epoch 35/50
# 171/171 [==============================] - 1s 3ms/step - loss: 0.0524 - Accuracy: 0.9874
# Epoch 36/50
# 171/171 [==============================] - 1s 4ms/step - loss: 0.0508 - Accuracy: 0.9881
# Epoch 37/50
# 171/171 [==============================] - 1s 4ms/step - loss: 0.1183 - Accuracy: 0.9764
# Epoch 38/50
# 171/171 [==============================] - 1s 3ms/step - loss: 0.0765 - Accuracy: 0.9815
# Epoch 39/50
# 171/171 [==============================] - 1s 4ms/step - loss: 0.0533 - Accuracy: 0.9872
# Epoch 40/50
# 171/171 [==============================] - 1s 6ms/step - loss: 0.0837 - Accuracy: 0.9841
# Epoch 41/50
# 171/171 [==============================] - 1s 6ms/step - loss: 0.0498 - Accuracy: 0.9881
# Epoch 42/50
# 171/171 [==============================] - 1s 4ms/step - loss: 0.0340 - Accuracy: 0.9903
# Epoch 43/50
# 171/171 [==============================] - 1s 4ms/step - loss: 0.0345 - Accuracy: 0.9930
# Epoch 44/50
# 171/171 [==============================] - 1s 4ms/step - loss: 0.0975 - Accuracy: 0.9912
# Epoch 45/50
# 171/171 [==============================] - 1s 3ms/step - loss: 0.0331 - Accuracy: 0.9923
# Epoch 46/50
# 171/171 [==============================] - 1s 4ms/step - loss: 0.0224 - Accuracy: 0.9954
# Epoch 47/50
# 171/171 [==============================] - 1s 4ms/step - loss: 0.0217 - Accuracy: 0.9952
# Epoch 48/50
# 171/171 [==============================] - 1s 4ms/step - loss: 0.0158 - Accuracy: 0.9967
# Epoch 49/50
# 171/171 [==============================] - 1s 4ms/step - loss: 0.0126 - Accuracy: 0.9967
# Epoch 50/50
# 171/171 [==============================] - 1s 3ms/step - loss: 0.0357 - Accuracy: 0.9943

# %%
print(X_test_ib.shape)
X_test_red_ib = pca_pc_ib.transform(X_test_ib)
y_pred_pca_ib = CBP_PCA_ib.predict(X_test_red_ib)


y_pred_pca_ib = y_pred_pca_ib.reshape(1364)
y_pred_pca_ib[y_pred_pca_ib > 0.3] = 1
y_pred_pca_ib[y_pred_pca_ib <= 0.3] = 0



print(y_pred_pca_ib.shape)
print(y_test_ib.shape)

# f1, precision, and recall scores
print("precision:", precision_score(y_test_ib, y_pred_pca_ib , average="macro"))
print("Recall:", recall_score(y_test_ib, y_pred_pca_ib , average="macro"))
print("F1_score:", f1_score(y_test_ib, y_pred_pca_ib , average="macro"))
# Out:
# (1364, 95)
# 43/43 [==============================] - 0s 2ms/step
# (1364,)
# (1364,)
# precision: 0.6326931176817454
# Recall: 0.6356060606060606
# F1_score: 0.6341310762077906

# %%
from sklearn.metrics import precision_recall_curve, PrecisionRecallDisplay,roc_curve,auc,RocCurveDisplay
# ROC curve
fpr_pca_ib, tpr_pca_ib, thresholds_pca_ib = roc_curve(y_test_ib, y_pred_pca_ib)
roc_auc_pca_ib = auc(fpr_pca_ib, tpr_pca_ib)
roc_display_pca_ib = RocCurveDisplay(fpr=fpr_pca_ib, tpr=tpr_pca_ib, roc_auc=roc_auc_pca_ib)
roc_display_pca_ib.plot()


# PR Curve
from sklearn.metrics import precision_recall_curve, PrecisionRecallDisplay
precision_pca_ib, recall_pca_ib, thresholds_pca_ib = precision_recall_curve(y_test_ib,y_pred_pca_ib)
pr_display_pca_ib = PrecisionRecallDisplay(precision=precision_pca_ib, recall=recall_pca_ib)
pr_display_pca_ib.plot()

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.85      0.87      2030
#            1       0.85      0.89      0.87      1930
#
#     accuracy                           0.87      3960
#    macro avg       0.87      0.87      0.87      3960
# weighted avg       0.87      0.87      0.87      3960

# %% [markdown]
# ##**PCA+RF+NN with SMOTE**

# %%
n_components = 30
pca30pc = PCA(n_components)
pca30pc.fit(X_train)
# Out:
# PCA(n_components=30)

# %%
plt.grid()
plt.plot(np.cumsum(pca30pc.explained_variance_ratio_))
plt.xlabel('Number of components')
plt.ylabel('Explained variance')
# Out:
# Text(0, 0.5, 'Explained variance')

# %%
# pca_30 = PCA(n_components = 0.95)
# pca_30.fit(X_train)
# print("Cumulative Variances (Percentage):")
# print(np.cumsum(pca_30.explained_variance_ratio_ * 100))
# components = len(pca_30.explained_variance_ratio_)
# print(f'Number of components: {components}')

# %%
num_pca_modes =11
pca30pc = PCA(n_components=num_pca_modes)
pca30pc.fit(X_train)

#pca90pc_comp  = abs(pca90pc.components_)
#print(pca90pc_comp)

X_train_red = pca30pc.transform(X_train)

print("Train images shape:", X_train_red.shape)
# Out:
# Train images shape: (9238, 11)

# %%
CBP_PCA = Sequential([keras.Input(shape=(num_pca_modes)),
                     Dense(50,activation="relu"),
                     Dense(30,activation="relu"),
                     Dense(20,activation="relu"),
                     Dense(1,activation="sigmoid")
                     ])

CBP_PCA.compile(optimizer="Adam",
                loss = "BinaryCrossentropy",
                metrics = "Accuracy")

CBP_PCA.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_9 (Dense)             (None, 50)                600
#
#  dense_10 (Dense)            (None, 30)                1530
#
#  dense_11 (Dense)            (None, 20)                620
#
#  dense_12 (Dense)            (None, 1)                 21
#
# =================================================================
# Total params: 2,771
# Trainable params: 2,771
# Non-trainable params: 0
# _________________________________________________________________

# %%
weights_pca = {0:1, 1:1}
history_pca = CBP_PCA.fit(X_train_red,y_train, epochs=70, class_weight=weights_pca)
# Out:
# Epoch 1/50
# 289/289 [==============================] - 2s 7ms/step - loss: 0.1502 - Accuracy: 0.9499
# Epoch 2/50
# 289/289 [==============================] - 1s 5ms/step - loss: 0.1431 - Accuracy: 0.9524
# Epoch 3/50
# 289/289 [==============================] - 2s 6ms/step - loss: 0.1425 - Accuracy: 0.9529
# Epoch 4/50
# 289/289 [==============================] - 1s 4ms/step - loss: 0.1413 - Accuracy: 0.9528
# Epoch 5/50
# 289/289 [==============================] - 1s 4ms/step - loss: 0.1429 - Accuracy: 0.9523
# Epoch 6/50
# 289/289 [==============================] - 1s 4ms/step - loss: 0.1391 - Accuracy: 0.9538
# Epoch 7/50
# 289/289 [==============================] - 1s 4ms/step - loss: 0.1390 - Accuracy: 0.9535
# Epoch 8/50
# 289/289 [==============================] - 1s 4ms/step - loss: 0.1424 - Accuracy: 0.9503
# Epoch 9/50
# 289/289 [==============================] - 1s 4ms/step - loss: 0.1404 - Accuracy: 0.9527
# Epoch 10/50
# 289/289 [==============================] - 1s 4ms/step - loss: 0.1362 - Accuracy: 0.9526
# Epoch 11/50
# 289/289 [==============================] - 1s 4ms/step - loss: 0.1369 - Accuracy: 0.9527
# Epoch 12/50
# 289/289 [==============================] - 1s 4ms/step - loss: 0.1391 - Accuracy: 0.9526
# Epoch 13/50
# 289/289 [==============================] - 2s 6ms/step - loss: 0.1379 - Accuracy: 0.9519
# Epoch 14/50
# 289/289 [==============================] - 1s 5ms/step - loss: 0.1320 - Accuracy: 0.9546
# Epoch 15/50
# 289/289 [==============================] - 1s 4ms/step - loss: 0.1312 - Accuracy: 0.9552
# Epoch 16/50
# 289/289 [==============================] - 1s 4ms/step - loss: 0.1327 - Accuracy: 0.9548
# Epoch 17/50
# 289/289 [==============================] - 1s 4ms/step - loss: 0.1325 - Accuracy: 0.9535
# Epoch 18/50
# 289/289 [==============================] - 1s 4ms/step - loss: 0.1295 - Accuracy: 0.9549
# Epoch 19/50
# 289/289 [==============================] - 1s 4ms/step - loss: 0.1257 - Accuracy: 0.9576
# Epoch 20/50
# 289/289 [==============================] - 1s 4ms/step - loss: 0.1342 - Accuracy: 0.9529
# Epoch 21/50
# 289/289 [==============================] - 1s 4ms/step - loss: 0.1331 - Accuracy: 0.9544
# Epoch 22/50
# 289/289 [==============================] - 1s 4ms/step - loss: 0.1216 - Accuracy: 0.9586
# Epoch 23/50
# 289/289 [==============================] - 1s 5ms/step - loss: 0.1280 - Accuracy: 0.9551
# Epoch 24/50
# 289/289 [==============================] - 2s 6ms/step - loss: 0.1214 - Accuracy: 0.9598
# Epoch 25/50
# 289/289 [==============================] - 1s 4ms/step - loss: 0.1255 - Accuracy: 0.9572
# Epoch 26/50
# 289/289 [==============================] - 1s 4ms/step - loss: 0.1261 - Accuracy: 0.9558
# Epoch 27/50
# 289/289 [==============================] - 1s 4ms/step - loss: 0.1205 - Accuracy: 0.9585
# Epoch 28/50
# 289/289 [==============================] - 1s 4ms/step - loss: 0.1169 - Accuracy: 0.9605
# Epoch 29/50
# 289/289 [==============================] - 1s 4ms/step - loss: 0.1181 - Accuracy: 0.9596
# Epoch 30/50
# 289/289 [==============================] - 1s 4ms/step - loss: 0.1178 - Accuracy: 0.9597
# Epoch 31/50
# 289/289 [==============================] - 1s 4ms/step - loss: 0.1142 - Accuracy: 0.9609
# Epoch 32/50
# 289/289 [==============================] - 1s 4ms/step - loss: 0.1147 - Accuracy: 0.9608
# Epoch 33/50
# 289/289 [==============================] - 1s 4ms/step - loss: 0.1101 - Accuracy: 0.9622
# Epoch 34/50
# 289/289 [==============================] - 1s 5ms/step - loss: 0.1102 - Accuracy: 0.9624
# Epoch 35/50
# 289/289 [==============================] - 1s 5ms/step - loss: 0.1166 - Accuracy: 0.9603
# Epoch 36/50
# 289/289 [==============================] - 1s 4ms/step - loss: 0.1076 - Accuracy: 0.9633
# Epoch 37/50
# 289/289 [==============================] - 1s 4ms/step - loss: 0.1086 - Accuracy: 0.9629
# Epoch 38/50
# 289/289 [==============================] - 1s 4ms/step - loss: 0.1111 - Accuracy: 0.9627
# Epoch 39/50
# 289/289 [==============================] - 1s 4ms/step - loss: 0.1102 - Accuracy: 0.9619
# Epoch 40/50
# 289/289 [==============================] - 1s 4ms/step - loss: 0.1061 - Accuracy: 0.9644
# Epoch 41/50
# 289/289 [==============================] - 1s 4ms/step - loss: 0.1059 - Accuracy: 0.9643
# Epoch 42/50
# 289/289 [==============================] - 1s 4ms/step - loss: 0.1063 - Accuracy: 0.9634
# Epoch 43/50
# 289/289 [==============================] - 1s 4ms/step - loss: 0.1036 - Accuracy: 0.9643
# Epoch 44/50
# 289/289 [==============================] - 1s 4ms/step - loss: 0.1103 - Accuracy: 0.9623
# Epoch 45/50
# 289/289 [==============================] - 2s 6ms/step - loss: 0.0998 - Accuracy: 0.9658
# Epoch 46/50
# 289/289 [==============================] - 1s 5ms/step - loss: 0.0992 - Accuracy: 0.9670
# Epoch 47/50
# 289/289 [==============================] - 1s 4ms/step - loss: 0.0997 - Accuracy: 0.9667
# Epoch 48/50
# 289/289 [==============================] - 1s 4ms/step - loss: 0.1015 - Accuracy: 0.9657
# Epoch 49/50
# 289/289 [==============================] - 1s 4ms/step - loss: 0.1012 - Accuracy: 0.9647
# Epoch 50/50
# 289/289 [==============================] - 1s 4ms/step - loss: 0.1026 - Accuracy: 0.9649

# %%
print(X_test.shape)
X_test_red = pca30pc.transform(X_test)
y_pred_pca = CBP_PCA.predict(X_test_red)

y_pred_pca = y_pred_pca.reshape(3960)
#y_pred_pca = y_pred_pca.reshape(2046)
y_pred_pca[y_pred_pca > 0.3] = 1
y_pred_pca[y_pred_pca <= 0.3] = 0

print(y_pred_pca.shape)
print(y_test.shape)

# f1, precision, and recall scores
print("precision:", precision_score(y_test, y_pred_pca , average="macro"))
print("Recall:", recall_score(y_test, y_pred_pca , average="macro"))
print("F1_score:", f1_score(y_test, y_pred_pca, average="macro"))
# Out:
# (3960, 30)
# 124/124 [==============================] - 0s 2ms/step
# (3960,)
# (3960,)
# precision: 0.9507360158774054
# Recall: 0.949706475407744
# F1_score: 0.9487267506640207

# %%
print(y_pred_pca.shape)
print(y_test.shape)
# Out:
# (3960,)
# (3960,)

# %%
from sklearn.metrics import precision_recall_curve, PrecisionRecallDisplay,roc_curve,auc,RocCurveDisplay
# ROC curve
fpr_pca, tpr_pca, thresholds_pca = roc_curve(y_test, y_pred_pca)
roc_auc_pca = auc(fpr_pca, tpr_pca)
roc_display_pca = RocCurveDisplay(fpr=fpr_pca, tpr=tpr_pca, roc_auc=roc_auc_pca)
roc_display_pca.plot()


# PR Curve
from sklearn.metrics import precision_recall_curve, PrecisionRecallDisplay
precision_pca, recall_pca, thresholds_pca = precision_recall_curve(y_test,y_pred_pca)
pr_display_pca = PrecisionRecallDisplay(precision=precision_pca, recall=recall_pca)
pr_display_pca.plot()

# %% [markdown]
# ##**Top features**

# %%
pca30pc.get_feature_names_out(input_features=None)

# %%
PCAs = []
for i in range(1,12):
    component_name = f"PC{i}"
    PCAs.append(component_name)

# %%
PC_df = pd.DataFrame(pca30pc.components_)
PC_df = PC_df.T
PC_df.columns = PCAs

# %%
fig, ax = plt.subplots(2, 1, figsize=(20,8), gridspec_kw={'height_ratios':[4,1]})
sns.heatmap(PC_df,ax = ax[0], cmap='coolwarm_r')
ax[0].set_xlabel('Principal Components')
ax[0].set_ylabel('weights of features')
ax[0].set_title('Feature weights corresponding to PCA')

ax[1].bar(PCAs, pca30pc.explained_variance_ratio_)
ax[1].set_xlabel('Principal Components (PC)')
ax[1].set_ylabel('Explained Var Ratio PCs')
plt.show()

# %%
Total_var = pca30pc.explained_variance_ratio_.sum()
print('Total variance captured by the PCs is %.2f' %Total_var)

# %%
PC_feature_names = []
PC_feature_weights = []
for PC in PCAs:
    dominant_features = np.abs(PC_df[PC]).sort_values(ascending = False)[:5]
    for i in dominant_features.index:
        PC_feature_weights.append(PC_df[PC][i])
    for i in dominant_features.index:
        PC_feature_names.append(X.columns[i])

# %%
PCA_df = []
for i in range(1,num_pca_modes+1):
    com_df_name = f"PC{i}_df"
    PCA_df.append(com_df_name)

for i in np.arange(1, 15, 5):
     PCA_df[int(i/5)]= pd.DataFrame(zip(PC_feature_names[i:i+5], PC_feature_weights[i:i+5]), columns = ['Feature names',  PCA_df[int(i/5)]])


PC_DF = PCA_df[0]
for i in np.arange(1, 3):
    PC_DF = PC_DF.merge(PCA_df[i], on='Feature names', how='outer')
PC_DF = PC_DF.fillna(0).set_index('Feature names')

# %%
print(PC_DF.shape)

# %%
plt.figure(figsize=(8,8))
sns.heatmap(PC_DF, cmap='coolwarm_r')
plt.title('Top three Principal components distribution')
plt.show()
